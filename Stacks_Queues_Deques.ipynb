# %% [markdown]
# # DATA STRUCTURES (VERİ YAPILARI)

# %% [markdown]
# ## Stacks - Queues - Deques

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Stack:
    
    def __init__(self):
        self.items=[]
    def isEmpty(self):
        """
            boş olup olmadigini kontrol eder.
        """
        return self.items==[]
    def push(self,item):
        self.items.append(item) #item ekleme
    def pop(self):
        self.items.pop() #item cikarma
    def top(self):
        return self.items[len(self.items)-1] # son elemani gosterme
    
    def size(self):
        return len(self.items)

# %%
stack=Stack()
print(stack.isEmpty())
stack.push("Erzurum")
print(stack.top())
stack.push("Ankara")
print(stack.top())
print(stack.size())
# Out:
# True
# Erzurum
# Ankara
# 2

# %% [markdown]
# ![8.jpg](attachment:8.jpg)

# %%
class Queu:
    def __init__(self):
        self.items=[]
    def isEmpty(self):
        return self.items==[]
    def enqueue(self,item):
        self.items.insert(0,item)
    def dequeue(self):
        return self.items.pop()
    def size(self):
        return len(self.items)

# %%
queue=Queu()
print(queue.isEmpty())
queue.enqueue("Erzurum")
queue.enqueue("Ankara")
queue.enqueue("Samsun")
print(queue.size())
queue.dequeue()
print(queue.size())
# Out:
# True
# 3
# 2

# %% [markdown]
# # deque

# %%
class Deque:
    def __init__(self):
        self.items=[]
    def isEmpty(self):
        return self.items==[]
    def addFront(self,item):
        self.items.append(item)
    def addRear(self,item):
        self.items.insert(0,item)
    def removeFront(self):
        return self.items.pop()
    def removeRear(self):
        return self.items.pop(0)
    def size(self):
        return len(self.items)

# %%
deque=Deque()
print(deque.isEmpty())
deque.addFront("ERZURUM")
deque.addRear("ANKARA")
print("size : ",deque.size())
deque.removeFront()
print("size : ",deque.size())
# Out:
# True
# size :  2
# size :  1

# %% [markdown]
# # Python Challenge/Problem

# %%
def createStack():
    stack=[]
    return stack
#stack size
def size(stack):
    pass
#stack boş mu?
def isEmpty(stack):
    pass
    #self.stack==[]
def top(stack):
    pass
def push(stack,item):
    stack.append(item)
def pop(stack):
    return stack.pop()
def reverse(string):
    n=len(string)
    stack=createStack()
    for i in range(n):
        push(stack,string[i])
    new_string=""
    for i in range(n):
        new_string+=pop(stack)
    return new_string

# %%
print("Mühendis: ",reverse("Mühendis"))
# Out:
# Mühendis:  sidnehüM

# %%
#stack kullanarak liste yapma
stack=["Mühendis","KRC","Erzurum",]
stack.append("Ankara")
stack.append("İzmir")
print(stack)
stack.pop()
print(stack)
# Out:
# ['Mühendis', 'KRC', 'Erzurum', 'Ankara', 'İzmir']
# ['Mühendis', 'KRC', 'Erzurum', 'Ankara']

# %%
#liste ve deque kullanarak queue yapma
from collections import deque
queue=deque(["Mühendis","KRC","Erzurum",])
print(queue)
queue.insert(0,"Ankara")
print(queue)
queue.pop()
print(queue)
# Out:
# deque(['Mühendis', 'KRC', 'Erzurum'])
# deque(['Ankara', 'Mühendis', 'KRC', 'Erzurum'])
# deque(['Ankara', 'Mühendis', 'KRC'])

# %%
#iki stack kullanarak queue yaratma
class Queue2Stack:
    def __init__(self):
        self.stack=[]
        self.stack1=[]
    def enqueue(self,item):
        self.stack.append(item)
    def dequeue(self):
        if not self.stack1:
            while len(self.stack)>0:
                self.stack1.append(self.stack.pop())
        return self.stack1.pop()

# %%
queue=Queue2Stack()
queue.enqueue("1")
queue.enqueue("2")
queue.enqueue("3")
print(queue.dequeue())
print(queue.dequeue())
# Out:
# 1
# 2
